# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # **Dheeraj Raj Ghai**
# Data Scientist

# %% [markdown]
# ## _I am interested in data science becasuse I want to analyse the material consumed on aviation industry and evaluate life cycle costing of an aircraft._

# %% [markdown]
# # My code show addition of two numbers x and y

# %%
x=1

# %%
y=2

# %%
x+y
# Out:
# 3

# %% [markdown]
# # My code showing a line
# ***

# %% [markdown]
# # My code showing numbers and bullets
#
#
#
# 1. Fruits
#     1. Mangoes
#     2. Apple
# 2. Vegetables
#     1. Beans
#     2. carrot
# 3. Dry fruits
#
#
# - Fruits
#     - Mangoes
#     - Apple
# - Vegetables
#     - Beans
#     - carrot
# - Dry fruits

# %% [markdown]
# #  My Code for  Table
#
# |sweet| |qty| |Cost|
# |----| |----| |----|
# |ladoo| |2| |2|
# |Jalebi| |3| |2|
# |kheer| |25| |2|
# |ladoo| |2| |2|
# |Jalebi| |3| |2|

# %% [markdown]
# # My code for  link with photo
#
# I Love [Python](https://python.org). Its a great language!
#
# ![Python Logo](https://www.python.org/static/img/python-logo@2x.png)

# %% [markdown]
# # My code for highlighting code/syntax
#
# Example:
# ```Python
# x = f(y)
# Print(x)
# ```

# %% [markdown]
# # My Code for blocking a quote
#
# # I will type "Hello My World" and  "My" will be missing
#
# # Hello
#
# > My
#
# # World

# %% [markdown]
# # Thanks for checking
